# %%
import csv
import tweepy
import ssl
import configparser
ssl._create_default_https_context = ssl._create_unverified_context

# read config
config = configparser.ConfigParser()
config.read('config.ini')

# Oauth keys
consumer_key = config['twitter']['api_key']
consumer_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

bearer_token = 'AAAAAAAAAAAAAAAAAAAAAD5SegEAAAAASH7Q1F2qlw5brHYabn8e6bEbvz4%3DQjnqieqMImwTIaTz7cpLGpLrBSDt7NPrJJeh6OUuqzsmDlWYp5'

# Authentication with Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# update these for the tweet you want to process replies to 'name' = the account username and you can find the tweet id within the tweet URL
# test tweet: https://twitter.com/NintendoAmerica/status/476399865652461568

name = 'NintendoAmerica'
tweet_id = '476399865652461568'
client = tweepy.Client(bearer_token = bearer_token)

query = "f'conversation_id:476399865652461568 to:NintendoAmerica"
start_time = '2014-06-09T00:00:00Z'
end_time = '2014-06-11T00:00:00Z'

# q = "curl --request GET \
#   --url 'https://api.twitter.com/2/tweets?ids=1225917697675886593&tweet.fields=author_id,conversation_id,created_at,in_reply_to_user_id,referenced_tweets&expansions=author_id,in_reply_to_user_id,referenced_tweets.id&user.fields=name,username' \
#   --header 'Authorization: Bearer $BEARER_TOKEN' "
replies=[]

# params = {'query': ',
#        'tweet.fields': 'in_reply_to_user_id', 
#        'tweet.fields':'conversation_id'
#    }

response = client.search_all_tweets(query=query, max_results=100, start_time=start_time, end_time=end_time)

#---
testp = []
for tweet in response.data:
    testp.append(tweet)
#---

# for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, start_time=start_time,result_type='recent', timeout=999999).items(1000):
#     if hasattr(tweet, 'in_reply_to_status_id_str'):
#         if (tweet.in_reply_to_status_id_str==tweet_id):
#             replies.append(tweet)

# with open('replies_clean.csv', 'w') as f:
#     csv_writer = csv.DictWriter(f, fieldnames=('user', 'text'))
#     csv_writer.writeheader()
#     for tweet in replies:
#         row = {'user': tweet.user.screen_name, 'text': tweet.text.replace('\n', ' ')}
#         csv_writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/7s/z8x5dbj52rq0td3yy2zcrqjc0000gn/T/ipykernel_5579/266097182.py in <module>
#      44 #    }
#      45
# ---> 46 response = client.search_all_tweets(query=query, max_results=100, start_time=start_time, end_time=end_time)
#      47
#      48 #---
#
# /opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py in search_all_tweets(self, query, **params)
#    1143         """
#    1144         params["query"] = query
# -> 1145         return self._make_request(
#    1146             "GET", "/2/tweets/search/all", params=params,
#    1147             endpoint_parameters=(
#
# /opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     124         request_params = self._process_params(params, endpoint_parameters)
#     125
# --> 126         response = self.request(method, route, params=request_params,
#     127                                 json=json, user_auth=user_auth)
#     128
#
# /opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py in request(self, method, route, params, json, user_auth)
#      93
#      94             if response.status_code == 400:
# ---> 95                 raise BadRequest(response)
#      96             if response.status_code == 401:
#      97                 raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# There were errors processing your request: Reference to invalid field 'f'conversation_id' (at position 1), Reference to invalid operator 'f'conversation_id'. Operator is not available in current product or product packaging. Please refer to complete available operator list at http://t.co/operators. (at position 1)

# %%
with open('replies_clean.csv', 'w') as f:
    csv_writer = csv.DictWriter(f, fieldnames=('user', 'text'))
    csv_writer.writeheader()
    for tweet in response:
        row = {tweet.text.replace('\n',' ')}
        csv_writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7s/z8x5dbj52rq0td3yy2zcrqjc0000gn/T/ipykernel_5579/3625632341.py in <module>
#       3     csv_writer.writeheader()
#       4     for tweet in response:
# ----> 5         row = {tweet.text.replace('\n',' ')}
#       6         csv_writer.writerow(row)
#
# AttributeError: 'list' object has no attribute 'text'

# %%
import csv
import tweepy
import ssl
import configparser

# read config
config = configparser.ConfigParser()
config.read('config.ini')

# Oauth keys
consumer_key = config['twitter']['api_key']
consumer_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

bearer_token = 'AAAAAAAAAAAAAAAAAAAAAD5SegEAAAAASH7Q1F2qlw5brHYabn8e6bEbvz4%3DQjnqieqMImwTIaTz7cpLGpLrBSDt7NPrJJeh6OUuqzsmDlWYp5'

# Authentication with Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# update these for the tweet you want to process replies to 'name' = the account username and you can find the tweet id within the tweet URL
# test tweet: https://twitter.com/NintendoAmerica/status/476399865652461568

name = 'NintendoAmerica'
tweet_id = '476399865652461568'
client = tweepy.Client(bearer_token = bearer_token)

query = "f'conversation_id:476399865652461568 to:NintendoAmerica"
start_time = '2014-06-09T00:00:00Z'
end_time = '2014-06-11T00:00:00Z'

# %%
t = client.get_tweet(476399865652461568)

# %%
t
# Out:
# Response(data=<Tweet id=476399865652461568 text='#Pokemon #OmegaRuby and #AlphaSapphire are coming to #Nintendo #3DS on November 21, 2014.'>, includes={}, errors=[], meta={})

# %%
t.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7s/z8x5dbj52rq0td3yy2zcrqjc0000gn/T/ipykernel_14593/2734992373.py in <module>
# ----> 1 t.data.type()
#
# /opt/anaconda3/lib/python3.9/site-packages/tweepy/mixins.py in __getattr__(self, name)
#      33             return self.data[name]
#      34         except KeyError:
# ---> 35             raise AttributeError from None
#      36
#      37     def __getitem__(self, key):
#
# AttributeError:
