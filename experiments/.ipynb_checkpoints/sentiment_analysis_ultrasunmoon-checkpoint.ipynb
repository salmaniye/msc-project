# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutomaticSpeechRecognitionPipeline

from scipy.special import softmax
import numpy as np
import pandas as pd

df = pd.read_excel('2. ORAS/combined_oras.xlsx')

# %%
len(df)
# Out:
# 88190

# %%
df = df[df['text'].str.contains('I liked a @YouTube video')== False]

# %%
len(df)
# Out:
# 63584

# %%
# Preprocessing
preprocessed_text = []

for tweet in df['text']:
    tweet_words = []
    for word in tweet.split(' '):
        if word.startswith('@') and len(word) > 1:
            word = '@user'
        elif word.startswith('http'):
            word = 'http'
        tweet_words.append(word)
    tweet_proc = " ".join(tweet_words)
    preprocessed_text.append(tweet_proc)

# %%
df['preprocessed tweets'] = preprocessed_text
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)
long_tweets = df['preprocessed tweets'].str.len().sort_values(ascending=False)

df.at[2870,'preprocessed tweets'] = 'OMG POKEMON ALPHA SAPPHIRE AND OMEGA RUBY'

# %%
# Load model and tokenizer

roberta = "cardiffnlp/twitter-roberta-base-sentiment-latest"
#roberta = "cardiffnlp/twitter-roberta-base-2021-124m"

model = AutoModelForSequenceClassification.from_pretrained(roberta)
tokenizer = AutoTokenizer.from_pretrained(roberta)

labels = ['Negative', 'Neutral', 'Positive']
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
sentiment_scores = []

for processed_tweet in df['preprocessed tweets']:
    encoded_tweet = tokenizer(processed_tweet, return_tensors='pt')

    output = model(**encoded_tweet)

    scores = output[0][0].detach().numpy()
    scores = softmax(scores)

    sentiment_scores.append(scores)

# %%
df['sentiment scores'] = sentiment_scores

# %%
import numpy as np

labels = ['Negative', 'Neutral', 'Positive']
index_no = [0,1,2]

label_dict = dict(zip(index_no, labels))

overall_sentiment = []

for sentiment_score in df['sentiment scores']:
    overall_sentiment.append(label_dict.get(sentiment_score.argmax()))

# %%
df['sentiment'] = overall_sentiment

# %%
df = df.drop(df.columns[[0]], axis=1)

# %%
from datetime import datetime

df['created at'] = df['created at'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %%
df.to_csv('pokemon_oras_tweets_datatset.csv')

# %%
df = df[df['text'].str.contains('I added a video to a @YouTube')== False]

# %%
len(df)
# Out:
# 61892

# %%
dfo = []
dfo = pd.read_excel('2. ORAS/combined_oras.xlsx')
dfo = dfo[dfo['text'].str.contains('I liked a @YouTube video')== False]
dfo['preprocessed tweets'] = preprocessed_text
dfo.at[2870,'preprocessed tweets'] = 'OMG POKEMON ALPHA SAPPHIRE AND OMEGA RUBY'
dfo = dfo.reset_index(drop=True)
dfo['sentiment scores'] = sentiment_scores
dfo['sentiment'] = overall_sentiment
dfo['created at'] = dfo['created at'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
dfo = dfo[dfo['text'].str.contains('I added a video to a @YouTube')== False]
dfo = dfo.reset_index(drop=True)
dfo.to_csv('pokemon_oras_tweets_datatset_fix.csv')
